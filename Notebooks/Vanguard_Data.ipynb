# %%
import pandas as pd
from Clean_Data import clean_vanguard_data

# %%
df = clean_vanguard_data()
display(df)

# %%
df['Variation'].value_counts(normalize=True)

# %%
df.groupby('Variation')[['calls_6_mnth', 'logons_6_mnth']].mean()

# %%
df.groupby('Variation')['clnt_age'].mean()

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.hist(df_final_Demo['bal'], bins=50)
plt.title("Distribution of Balance (Raw)")
plt.xlabel("Balance")
plt.ylabel("Frequency")
plt.show()
