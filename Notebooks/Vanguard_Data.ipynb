# %%
import pandas as pd
from Clean_Data import clean_rows_tenure_above_age

# %%
# Reading the Data files
url = "https://raw.githubusercontent.com/data-bootcamp-v4/lessons/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_demo.txt"
df_final_Demo = pd.read_csv(url, on_bad_lines='skip')

url = "https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_web_data_pt_1.txt"
df_final_web_data_pt_1 = pd.read_csv(url, on_bad_lines='skip')

url = "https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_web_data_pt_2.txt"
df_final_web_data_pt_2 = pd.read_csv(url, on_bad_lines='skip')

url = "https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_experiment_clients.txt"
df_final_experiment_clients = pd.read_csv(url, on_bad_lines='skip')

# Displaying the Data from the files
print(df_final_Demo.shape)
display(df_final_Demo.head(10))
# Out:
# (70609, 9)
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0     836976             6.0              73.0      60.5     U        2.0
# 1    2304905             7.0              94.0      58.0     U        2.0
# 2    1439522             5.0              64.0      32.0     U        2.0
# 3    1562045            16.0             198.0      49.0     M        2.0
# 4    5126305            12.0             145.0      33.0     F        2.0
# 5    3727881             5.0              71.0      30.5     U        2.0
# 6     272934             5.0              66.0      58.5     U        2.0
# 7     388801            30.0             361.0      57.5     M        5.0
# 8     285619            30.0             369.0      67.5     M        2.0
# 9    8198645            15.0             189.0      54.5     F        2.0
#
#          bal  calls_6_mnth  logons_6_mnth
# 0   45105.30           6.0            9.0
# 1  110860.30           6.0            9.0
# 2   52467.79           6.0            9.0
# 3   67454.65           3.0            6.0
# 4  103671.75           0.0            3.0
# 5   23915.60           0.0            3.0
# 6   27021.42           2.0            5.0
# 7  522498.72           1.0            4.0
# 8  299388.72           3.0            6.0
# 9  382303.83           6.0            9.0

# %%
display(df_final_web_data_pt_1.head(10))
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 5    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 6    9988021  580560515_7732621733  781255054_21935453173_531117       step_1
# 7    9988021  580560515_7732621733  781255054_21935453173_531117        start
# 8    8320017  39393514_33118319366  960651974_70596002104_312201      confirm
# 9    8320017  39393514_33118319366  960651974_70596002104_312201       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# 3  2017-04-17 15:19:13
# 4  2017-04-17 15:18:04
# 5  2017-04-17 15:17:15
# 6  2017-04-17 15:17:01
# 7  2017-04-17 15:16:22
# 8  2017-04-05 13:10:05
# 9  2017-04-05 13:09:43

# %%
display(df_final_web_data_pt_2.head(10))
# Out:
#    client_id             visitor_id                      visit_id  \
# 0     763412  601952081_10457207388  397475557_40440946728_419634
# 1    6019349  442094451_91531546617  154620534_35331068705_522317
# 2    6019349  442094451_91531546617  154620534_35331068705_522317
# 3    6019349  442094451_91531546617  154620534_35331068705_522317
# 4    6019349  442094451_91531546617  154620534_35331068705_522317
# 5    6019349  442094451_91531546617  154620534_35331068705_522317
# 6    4726500  934350987_45569789638  467318052_88159801968_565608
# 7    4726500  934350987_45569789638  467318052_88159801968_565608
# 8    4726500  934350987_45569789638  467318052_88159801968_565608
# 9    4726500  934350987_45569789638  467318052_88159801968_565608
#
#   process_step            date_time
# 0      confirm  2017-06-06 08:56:00
# 1      confirm  2017-06-01 11:59:27
# 2       step_3  2017-06-01 11:58:48
# 3       step_2  2017-06-01 11:58:08
# 4       step_1  2017-06-01 11:57:58
# 5        start  2017-06-01 11:57:54
# 6      confirm  2017-06-05 17:38:52
# 7       step_3  2017-06-05 17:38:33
# 8       step_2  2017-06-05 17:37:31
# 9       step_1  2017-06-05 17:37:24

# %%
display(df_final_experiment_clients.head(10))
# Out:
#    client_id Variation
# 0    9988021      Test
# 1    8320017      Test
# 2    4033851   Control
# 3    1982004      Test
# 4    9294070   Control
# 5    9466803      Test
# 6    3170143      Test
# 7    6651403   Control
# 8    5887227      Test
# 9    2105948   Control

# %% [markdown]
# Shape of our Datasets

# %%
print("Shape of df_final_Demo dataset: ",df_final_Demo.shape)
print("Shape of df_final_web_data_pt_1 dataset: ",df_final_web_data_pt_1.shape)
print("Shape of df_final_web_data_pt_2 dataset: ",df_final_web_data_pt_2.shape)
print("Shape of df_final_experiment_clients dataset: ",df_final_experiment_clients.shape)
# Out:
# Shape of df_final_Demo dataset:  (70609, 9)
# Shape of df_final_web_data_pt_1 dataset:  (343141, 5)
# Shape of df_final_web_data_pt_2 dataset:  (412264, 5)
# Shape of df_final_experiment_clients dataset:  (70609, 2)

# %% [markdown]
# Check if any Duplicate rows in these 4 datasets

# %%
print("Duplicate rows in df_final_Demo dataset: ",df_final_Demo.duplicated().sum())
print("Duplicate rows in df_final_web_data_pt_1 dataset: ", df_final_web_data_pt_1.duplicated().sum())
print("Duplicate rows in df_final_web_data_pt_2 dataset: ",df_final_web_data_pt_2.duplicated().sum())
print("Duplicate rows in df_final_experiment_clients dataset: ",df_final_experiment_clients.duplicated().sum())
# Out:
# Duplicate rows in df_final_Demo dataset:  0
# Duplicate rows in df_final_web_data_pt_1 dataset:  2095
# Duplicate rows in df_final_web_data_pt_2 dataset:  8669
# Duplicate rows in df_final_experiment_clients dataset:  0

# %% [markdown]
# Drop duplicates

# %%
df_final_Demo = df_final_Demo.drop_duplicates()
df_final_web_data_pt_1 = df_final_web_data_pt_1.drop_duplicates()
df_final_web_data_pt_2 = df_final_web_data_pt_2.drop_duplicates()
df_final_experiment_clients = df_final_experiment_clients.drop_duplicates()

# %% [markdown]
# Just checking if all duplicates got deleted

# %%
print("Duplicate rows in df_final_Demo dataset: ",df_final_Demo.duplicated().sum())
print("Duplicate rows in df_final_web_data_pt_1 dataset: ", df_final_web_data_pt_1.duplicated().sum())
print("Duplicate rows in df_final_web_data_pt_2 dataset: ",df_final_web_data_pt_2.duplicated().sum())
print("Duplicate rows in df_final_experiment_clients dataset: ",df_final_experiment_clients.duplicated().sum())
# Out:
# Duplicate rows in df_final_Demo dataset:  0
# Duplicate rows in df_final_web_data_pt_1 dataset:  0
# Duplicate rows in df_final_web_data_pt_2 dataset:  0
# Duplicate rows in df_final_experiment_clients dataset:  0

# %% [markdown]
# Checking for Nulls in datasets

# %%
print("Nulls in df_final_Demo dataset: ",df_final_Demo.isnull().sum())
print("Nulls in df_final_web_data_pt_1 dataset: ", df_final_web_data_pt_1.isnull().sum())
print("Nulls in df_final_web_data_pt_2 dataset: ",df_final_web_data_pt_2.isnull().sum())
print("Nulls in df_final_experiment_clients dataset: ",df_final_experiment_clients.isnull().sum())
# Out:
# Nulls in df_final_Demo dataset:  client_id            0
# clnt_tenure_yr      14
# clnt_tenure_mnth    14
# clnt_age            15
# gendr               14
# num_accts           14
# bal                 14
# calls_6_mnth        14
# logons_6_mnth       14
# dtype: int64
# Nulls in df_final_web_data_pt_1 dataset:  client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# date_time       0
# dtype: int64
# Nulls in df_final_web_data_pt_2 dataset:  client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# date_time       0
# dtype: int64
# Nulls in df_final_experiment_clients dataset:  client_id        0
# Variation    20109
# dtype: int64

# %% [markdown]
# Just 2 tables have nulls : df_final_Demo  and df_final_experiment_clients
# Displying the nulls in the form of percentages in these 2 tables

# %%
print("Nulls in df_final_Demo dataset (%):\n",
      df_final_Demo.isnull().sum() / len(df_final_Demo) * 100)

print("\n\nNulls in df_final_experiment_clients dataset (%):\n",
      df_final_experiment_clients.isnull().sum() / len(df_final_experiment_clients) * 100)
# Out:
# Nulls in df_final_Demo dataset (%):
#  client_id           0.000000
# clnt_tenure_yr      0.019828
# clnt_tenure_mnth    0.019828
# clnt_age            0.021244
# gendr               0.019828
# num_accts           0.019828
# bal                 0.019828
# calls_6_mnth        0.019828
# logons_6_mnth       0.019828
# dtype: float64
#
#
# Nulls in df_final_experiment_clients dataset (%):
#  client_id     0.000000
# Variation    28.479372
# dtype: float64

# %% [markdown]
# As duplicates % too small in table df_final_Demo , we can drop those rows

# %%
df_final_Demo = df_final_Demo.dropna().reset_index(drop=True)

# %%
print("DataSet Length: ", len(df_final_experiment_clients))
print("DataSet Null Sum: ", df_final_experiment_clients['Variation'].isnull().sum())
# Out:
# DataSet Length:  70609
# DataSet Null Sum:  20109

# %%
counts = df_final_experiment_clients['client_id'].value_counts()
duplicate_ids = counts[counts > 1].index
df_final_experiment_clients[df_final_experiment_clients['client_id'].isin(duplicate_ids)]
# Out:
# Empty DataFrame
# Columns: [client_id, Variation]
# Index: []

# %% [markdown]
# df_final_experiment_clients contains 28% nulls in Variation column, we should think how to handle it:
# But like just important column in this dataset is Variation column,and that contains nulls we should drop those rows, because those rows will not be useful. or we can put defaukt value 'Unknown'

# %% [markdown]
# Appending data from df_final_web_data_pt_2 to df_final_web_data_pt_1 dataset

# %% [markdown]
# Check the datatypes

# %% [markdown]
# All datatypes are ok, except the date_time which is object and we need to convert it to datetime

# %%
df_final_web_data_combined = pd.concat([df_final_web_data_pt_1, df_final_web_data_pt_2], axis=0, ignore_index=True)
df_final_web_data_combined["date_time"] = pd.to_datetime(df_final_web_data_combined["date_time"])

# %%
df_final_web_data_combined.dtypes
# Out:
# client_id                int64
# visitor_id                 str
# visit_id                   str
# process_step               str
# date_time       datetime64[us]
# dtype: object

# %% [markdown]
# Check if any outlier or different value in numeric columns by seeing there, mean, median, max etc..

# %%
print("df_final_Demo dataset: \n",df_final_Demo.describe())
print("\n\ndf_final_web_data_combined dataset: \n", df_final_web_data_combined.describe())
# Out:
# df_final_Demo dataset:
#            client_id  clnt_tenure_yr  clnt_tenure_mnth      clnt_age  \
# count  7.059400e+04    70594.000000      70594.000000  70594.000000
# mean   5.005026e+06       12.053007        150.659999     46.442240
# std    2.877289e+06        6.871850         82.090264     15.591273
# min    1.690000e+02        2.000000         33.000000     13.500000
# 25%    2.519543e+06        6.000000         82.000000     32.500000
# 50%    5.016974e+06       11.000000        136.000000     47.000000
# 75%    7.483074e+06       16.000000        192.000000     59.000000
# max    9.999839e+06       62.000000        749.000000     96.000000
#
#           num_accts           bal  calls_6_mnth  logons_6_mnth
# count  70594.000000  7.059400e+04  70594.000000   70594.000000
# mean       2.255532  1.474467e+05      3.382469       5.566720
# std        0.535000  3.015106e+05      2.236595       2.353296
# min        1.000000  1.378942e+04      0.000000       1.000000
# 25%        2.000000  3.734660e+04      1.000000       4.000000
# 50%        2.000000  6.333459e+04      3.000000       5.000000
# 75%        2.000000  1.375461e+05      6.000000       7.000000
# max        8.000000  1.632004e+07      7.000000       9.000000
#
#
# df_final_web_data_combined dataset:
#            client_id                   date_time
# count  7.446410e+05                      744641
# mean   5.014059e+06  2017-05-07 20:56:25.995346
# min    1.690000e+02         2017-03-15 00:03:03
# 25%    2.521851e+06         2017-04-08 16:57:49
# 50%    5.031965e+06         2017-05-11 23:29:48
# 75%    7.497388e+06         2017-06-03 12:12:46
# max    9.999875e+06         2017-06-20 23:59:57
# std    2.879588e+06                         NaN

# %% [markdown]
# Bryan

# %%
print(df_final_Demo["gendr"].value_counts())  ##
df_final_Demo["gendr"] = df_final_Demo["gendr"].replace(["X"], "Unknown")
df_final_Demo['gendr'] = df_final_Demo['gendr'].replace('U', 'Unknown')
print(df_final_Demo["gendr"].value_counts())
# Out:
# gendr
# U    24122
# M    23724
# F    22745
# X        3
# Name: count, dtype: int64
# gendr
# Unknown    24125
# M          23724
# F          22745
# Name: count, dtype: int64

# %%
print(df_final_Demo["num_accts"].value_counts()) ## we have some categories with fewer observations.
# Out:
# num_accts
# 2.0    55496
# 3.0    12529
# 4.0     2241
# 5.0      284
# 6.0       33
# 7.0        8
# 1.0        2
# 8.0        1
# Name: count, dtype: int64

# %%
df_final_Demo["bal"].describe().T
# Out:
# count    7.059400e+04
# mean     1.474467e+05
# std      3.015106e+05
# min      1.378942e+04
# 25%      3.734660e+04
# 50%      6.333459e+04
# 75%      1.375461e+05
# max      1.632004e+07
# Name: bal, dtype: float64

# %%
df_final_web_data_combined = df_final_web_data_combined.drop(columns=['visitor_id'])
display(df_final_web_data_combined)
# Out:
#         client_id                      visit_id process_step  \
# 0         9988021  781255054_21935453173_531117       step_3
# 1         9988021  781255054_21935453173_531117       step_2
# 2         9988021  781255054_21935453173_531117       step_3
# 3         9988021  781255054_21935453173_531117       step_2
# 4         9988021  781255054_21935453173_531117       step_3
# ...           ...                           ...          ...
# 744636    9668240   922267647_3096648104_968866        start
# 744637    9668240   922267647_3096648104_968866        start
# 744638    9668240   922267647_3096648104_968866       step_1
# 744639    9668240   922267647_3096648104_968866        start
# 744640     674799   86152093_47511127657_716022        start
#
#                  date_time
# 0      2017-04-17 15:27:07
# 1      2017-04-17 15:26:51
# 2      2017-04-17 15:19:22
# 3      2017-04-17 15:19:13
# 4      2017-04-17 15:18:04
# ...                    ...
# 744636 2017-05-24 18:46:10
# 744637 2017-05-24 18:45:29
# 744638 2017-05-24 18:44:51
# 744639 2017-05-24 18:44:34
# 744640 2017-06-03 12:17:09
#
# [744641 rows x 4 columns]

# %%
df_final_merged = pd.merge(df_final_Demo, df_final_web_data_combined, on='client_id', how='inner')
display(df_final_merged)
# Out:
#         client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age    gendr  \
# 0          836976             6.0              73.0      60.5  Unknown
# 1          836976             6.0              73.0      60.5  Unknown
# 2          836976             6.0              73.0      60.5  Unknown
# 3          836976             6.0              73.0      60.5  Unknown
# 4          836976             6.0              73.0      60.5  Unknown
# ...           ...             ...               ...       ...      ...
# 443767    5602139            21.0             254.0      59.5        F
# 443768    5602139            21.0             254.0      59.5        F
# 443769    5602139            21.0             254.0      59.5        F
# 443770    5602139            21.0             254.0      59.5        F
# 443771    5602139            21.0             254.0      59.5        F
#
#         num_accts        bal  calls_6_mnth  logons_6_mnth  \
# 0             2.0   45105.30           6.0            9.0
# 1             2.0   45105.30           6.0            9.0
# 2             2.0   45105.30           6.0            9.0
# 3             2.0   45105.30           6.0            9.0
# 4             2.0   45105.30           6.0            9.0
# ...           ...        ...           ...            ...
# 443767        3.0  157498.73           7.0            7.0
# 443768        3.0  157498.73           7.0            7.0
# 443769        3.0  157498.73           7.0            7.0
# 443770        3.0  157498.73           7.0            7.0
# 443771        3.0  157498.73           7.0            7.0
#
#                             visit_id process_step           date_time
# 0        228976764_46825473280_96584      confirm 2017-04-02 11:51:13
# 1        228976764_46825473280_96584      confirm 2017-04-02 11:47:50
# 2        228976764_46825473280_96584      confirm 2017-04-02 11:46:45
# 3        228976764_46825473280_96584       step_3 2017-04-02 11:23:08
# 4        228976764_46825473280_96584       step_2 2017-04-02 11:22:24
# ...                              ...          ...                 ...
# 443767    158544612_4105226940_43043      confirm 2017-04-05 11:48:02
# 443768    158544612_4105226940_43043       step_3 2017-04-05 11:44:07
# 443769    158544612_4105226940_43043       step_2 2017-04-05 11:43:10
# 443770  884309593_49820690623_654151       step_1 2017-04-05 11:41:32
# 443771  884309593_49820690623_654151        start 2017-04-05 11:41:04
#
# [443772 rows x 12 columns]

# %%
df_exp = df_final_merged.merge(df_final_experiment_clients, on='client_id', how='inner')
display(df_exp)
# Out:
#         client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age    gendr  \
# 0          836976             6.0              73.0      60.5  Unknown
# 1          836976             6.0              73.0      60.5  Unknown
# 2          836976             6.0              73.0      60.5  Unknown
# 3          836976             6.0              73.0      60.5  Unknown
# 4          836976             6.0              73.0      60.5  Unknown
# ...           ...             ...               ...       ...      ...
# 443767    5602139            21.0             254.0      59.5        F
# 443768    5602139            21.0             254.0      59.5        F
# 443769    5602139            21.0             254.0      59.5        F
# 443770    5602139            21.0             254.0      59.5        F
# 443771    5602139            21.0             254.0      59.5        F
#
#         num_accts        bal  calls_6_mnth  logons_6_mnth  \
# 0             2.0   45105.30           6.0            9.0
# 1             2.0   45105.30           6.0            9.0
# 2             2.0   45105.30           6.0            9.0
# 3             2.0   45105.30           6.0            9.0
# 4             2.0   45105.30           6.0            9.0
# ...           ...        ...           ...            ...
# 443767        3.0  157498.73           7.0            7.0
# 443768        3.0  157498.73           7.0            7.0
# 443769        3.0  157498.73           7.0            7.0
# 443770        3.0  157498.73           7.0            7.0
# 443771        3.0  157498.73           7.0            7.0
#
#                             visit_id process_step           date_time  \
# 0        228976764_46825473280_96584      confirm 2017-04-02 11:51:13
# 1        228976764_46825473280_96584      confirm 2017-04-02 11:47:50
# 2        228976764_46825473280_96584      confirm 2017-04-02 11:46:45
# 3        228976764_46825473280_96584       step_3 2017-04-02 11:23:08
# 4        228976764_46825473280_96584       step_2 2017-04-02 11:22:24
# ...                              ...          ...                 ...
# 443767    158544612_4105226940_43043      confirm 2017-04-05 11:48:02
# 443768    158544612_4105226940_43043       step_3 2017-04-05 11:44:07
# 443769    158544612_4105226940_43043       step_2 2017-04-05 11:43:10
# 443770  884309593_49820690623_654151       step_1 2017-04-05 11:41:32
# 443771  884309593_49820690623_654151        start 2017-04-05 11:41:04
#
#        Variation
# 0           Test
# 1           Test
# 2           Test
# 3           Test
# 4           Test
# ...          ...
# 443767       NaN
# 443768       NaN
# 443769       NaN
# 443770       NaN
# 443771       NaN
#
# [443772 rows x 13 columns]

# %%
df_exp['Variation'].value_counts(normalize=True)
# Out:
# Variation
# Test       0.534019
# Control    0.465981
# Name: proportion, dtype: float64

# %%
df_exp.groupby('Variation')[['calls_6_mnth', 'logons_6_mnth']].mean()
# Out:
#            calls_6_mnth  logons_6_mnth
# Variation
# Control        3.129176       6.166242
# Test           3.061941       6.101851

# %%
df_exp.groupby('Variation')['clnt_age'].mean()
# Out:
# Variation
# Control    47.498427
# Test       47.163922
# Name: clnt_age, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.hist(df_final_Demo['bal'], bins=50)
plt.title("Distribution of Balance (Raw)")
plt.xlabel("Balance")
plt.ylabel("Frequency")
plt.show()
